# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKP01/simulationlab/blob/main/simulation_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as p
import numpy as np
Hr=int(input("Enter how many harmonics do u want: "))
l=int(input("Enter length of the box: "))
N=np.linspace(1,Hr, Hr)
for n in N:
  x=np.linspace(0,l, 1000)
  y=((np.sqrt(2/l)*np.sin((n*np.pi*x)/l))+n)
  p.plot(x,y)
# Out:
# Enter how many harmonics do u want: 6
# Enter length of the box: 9

# %% [markdown]
# root(2)/lsin (npix/l)

# %% [markdown]
# motion of a sperical body falling in a viscous medium. Mass of the body is m. It experiances two forces. viscous drag force in upward direction and gravitational force in downward direction.Net force acting on the body F=mg-(6* pi * eta * r * v).
# Acceleration is dv/dt =g-cv ,c=(6* pi * eta * r)/m.
# g=9.8, eta=10.5 ,r=0.0025 ,initial vel=0 , max time =0.005sec , number of time step= 25 , step size=0.0002, m=0.0005

# %%
import numpy as np
import matplotlib.pyplot as p
g=9.8
eta=10.5
r=0.0025
tmax=0.005
m=0.0005
tspt=25
tsize=0.0002
pi=3.14
v=(m*g)+20
V=[]
T=np.arange(0,0.005,0.0002)
for t in T:
  V.append(v)
  print("For time ",t,"Velocity is", v)
  c=((6*pi*eta*r)/m)
  F=(m*g)-(m*c*v)
  A=g-(c*v)
  v=v+(A*tsize)
p.plot(T,V)
p.xlabel("Time (s)")
p.ylabel("Velocity (m/s)")
# Out:
# For time  0.0 Velocity is 20.0049
# For time  0.0002 Velocity is 16.049490682
# For time  0.0004 Velocity is 12.876540435286758
# For time  0.0006000000000000001 Velocity is 10.331263206378331
# For time  0.0008 Velocity is 8.28949271889257
# For time  0.001 Velocity is 6.651625269241242
# For time  0.0012000000000000001 Velocity is 5.33776075847994
# For time  0.0014 Velocity is 4.283804925237439
# For time  0.0016 Velocity is 3.4383426349269683
# For time  0.0018000000000000002 Velocity is 2.7601296948857157
# For time  0.002 Velocity is 2.2160808386434234
# For time  0.0022 Velocity is 1.7796557271429814
# For time  0.0024000000000000002 Velocity is 1.429564231199557
# For time  0.0026000000000000003 Velocity is 1.1487278349836605
# For time  0.0028 Velocity is 0.9234464946671928
# For time  0.003 Velocity is 0.7427303090921287
# For time  0.0032 Velocity is 0.5977633993475238
# For time  0.0034000000000000002 Velocity is 0.4814738436885966
# ...

# %% [markdown]
# f=ma , d^2(x)/dt^2=-(w0)^2x
# dv/dt=-(w0)^2x
# dv/dt=f(t,v(t),X(t))
# tn+1=tn+(h)
# vn=vn+h*f(tn,vn,Xn)
# xn+1=xn+hf(tn,vn,Xn)
# initial values
# spring const=2N/m
# mass of the block = 1 Kg
# initial position = 1.5 m
# initial velocity = 0
# max time = 10  sec
# number of steps = 100

# %%
import numpy as np
import matplotlib.pyplot as p
k=2
m=1
tmax=10
v=0
x=1.5
tsize=10/100
X=[]
V=[]
T=np.arange(0,10.1,0.1)
for t in T:
  X.append(x)
  V.append(v)
  a=(((-k)*x)/m)
  v=v+(a*tsize)
  x=x+(v*tsize)
p.subplot(2,1,1)
p.plot(T,X)
p.xlabel("Time (s)")
p.ylabel("displacement (m)")
p.subplot(2,1,2)
p.plot(T,V)
p.xlabel("Time (s)")
p.ylabel("Velocity (m/s)")
# Out:
# <class 'numpy.ndarray'>
# Text(0, 0.5, 'Velocity (m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
k=2
m=1
tmax=10
v=0
x=1.5
tsize=10/100
X=[]
V=[]
A=[]
T=np.arange(0,10.1,0.1)
for t in T:
  X.append(x)
  V.append(v)
  a=(((-k)*x)/m)
  A.append(a)
  v=v+(a*tsize)
  x=x+(v*tsize)
fig, axs = p.subplots(2, 2, gridspec_kw={'hspace': 0.5, 'wspace': 0.5})
axs[0, 0].plot(T,X)
axs[0, 0].set_xlabel("Time (s)")
axs[0, 0].set_ylabel("displacement (m)")
axs[0, 1].plot(T,V)
axs[0, 1].set_xlabel("Time (s)")
axs[0, 1].set_ylabel("Velocity (m/s)")
axs[1, 0].plot(T,A)
axs[1, 0].set_xlabel("Time (s)")
axs[1, 0].set_ylabel("Acceleration (m/s^2)")
axs[1, 1].plot(X,V)
axs[1, 1].set_xlabel("Displacement (m)")
axs[1, 1].set_ylabel("Velocity(m/s)")
# Out:
# Text(0, 0.5, 'Velocity(m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
k=2
m=1
tmax=10
v=0
x=1.5
tsize=10/100
b=0.2
X=[]
V=[]
A=[]
T=np.arange(0,10.1,0.1)
for t in T:
  X.append(x)
  V.append(v)
  a=((-2*v*b)-(((k)*x)/m))
  A.append(a)
  v=v+(a*tsize)
  x=x+(v*tsize)
fig, axs = p.subplots(2, 2, gridspec_kw={'hspace': 0.5, 'wspace': 0.5})
axs[0, 0].plot(T,X)
axs[0, 0].set_xlabel("Time (s)")
axs[0, 0].set_ylabel("displacement (m)")
axs[0, 1].plot(T,V)
axs[0, 1].set_xlabel("Time (s)")
axs[0, 1].set_ylabel("Velocity (m/s)")
axs[1, 0].plot(T,A)
axs[1, 0].set_xlabel("Time (s)")
axs[1, 0].set_ylabel("Acceleration (m/s^2)")
axs[1, 1].plot(X,V)
axs[1, 1].set_xlabel("Displacement (m)")
axs[1, 1].set_ylabel("Velocity(m/s)")
# Out:
# Text(0, 0.5, 'Velocity(m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
k=2
m=1
tmax=10
v=0
x=1.5
tsize=10/100
b=0.2
X=[]
V=[]
A=[]
T=np.arange(0,10.1,0.1)
for t in T:
  X.append(x)
  V.append(v)
  a=((-2*v*b)-(((k)*x)/m))
  A.append(a)
  v=v+(a*tsize)
  x=x+(v*tsize)
fig, axs = p.subplots(2, 2, gridspec_kw={'hspace': 0.5, 'wspace': 0.5})
axs[0, 0].plot(T,X)
axs[0, 0].set_xlabel("Time (s)")
axs[0, 0].set_ylabel("displacement (m)")
axs[0, 1].plot(T,V)
axs[0, 1].set_xlabel("Time (s)")
axs[0, 1].set_ylabel("Velocity (m/s)")
axs[1, 0].plot(T,A)
axs[1, 0].set_xlabel("Time (s)")
axs[1, 0].set_ylabel("Acceleration (m/s^2)")
axs[1, 1].plot(X,V)
axs[1, 1].set_xlabel("Displacement (m)")
axs[1, 1].set_ylabel("Velocity(m/s)")
# Out:
# Text(0, 0.5, 'Velocity(m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
m=5
g=9.8
vx=300
vy=0
x=0
y=0
tmax=12
h=500
X=[]
Y=[]
T=np.arange(0,12.1,0.1)
for t in T:
  a=-g
  X.append(x)
  Y.append(y)
  vy=a*t
  y=vy*t
  x=vx*t
p.plot(X,Y)

# %%
import numpy as np
import matplotlib.pyplot as p
m=0.005
v1=49
g=9.8
c=0.01
Q=30
r=0.01
vy=49
y=0
tmax=5
tsize=0.01
V=[]
Y=[]
T=np.arange(0,10.01,0.01)
for t in T:
  V.append(vy)
  Y.append(y)
  ay=-g
  vy=vy+(ay*tsize)
  y=y+(vy*tsize)
p.subplot(211)
p.plot(T,V)
p.xlabel('Time (s)')
p.ylabel('Velocity (m/s)')
p.title('Projectile Motion:velocity vs Time')
p.subplots_adjust(hspace=0.5)
p.subplot(212)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('position(m/s)')
# Out:
# Text(0, 0.5, 'position(m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
m=0.005
v1=49
g=9.8
vx=300
c=0.01
Q=30
r=0.01
vy=np.sin(Q)
vx=np.cos(Q)
x=0
y=0
tmax=5
tsize=0.01
V=[]
Y=[]
T=np.arange(0,5.1,0.01)
for t in T:
  f=((1/(2*m))*c*3.14*(r*r)*(v1*v1))
  ax=((-f/m)*np.cos(Q))
  ay=((-g)-((f/m)*np.sin(Q)))
  vx=vx+(ax*tsize)
  vy=vy+(ay*tsize)
  Q=np.arccos(vx/(np.sqrt((vx*vx)+(vy*vy))))
  v1=np.sqrt((vx*vx)+(vy*vy))
  V.append(v1)
  vy=g*tsize
  y=vy*tsize
  x=vx*t
p.plot(T,V)

# %%
import numpy as np
import matplotlib.pyplot as p
m=5
g=9.8
vx=300
vy=0
h=500
x=0
y=h
tmax=12
X=[]
Y=[]
T=np.arange(0,10.1,0.1)
for t in T:
  a=-g
  X.append(x)
  Y.append(y)
  vy=vy+(a*0.1)
  y=y+(vy*0.1)
  x=x+(vx*0.1)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('Position(m/s)')
# Out:
# Text(0, 0.5, 'Position(m/s)')

# %%
import numpy as np
import matplotlib.pyplot as p
q1=-3e-9
q2=7e-9
k=9e9
x1=0.2
y1=0.3
x2=-0.3
y2=-0.2
xp=-0.1
yp=-0.2
a1=xp-x1
b1=xp-y1
a1sqr=np.square(a1)
b1sqr=np.square(b1)
mag_r1=np.sqrt(a1sqr+b1sqr)
E1=(k*q1)/(np.square(mag_r1))
a2=xp-x2
b2=xp-y2
a2sqr=np.square(a2)
b2sqr=np.square(b2)
mag_r2=np.sqrt(a2sqr+b2sqr)
E2=(k*q2)/(np.square(mag_r2))
E=E1+E2
print("electreic field =", E)
# Out:
# electreic field = 1152.0

# %%
import numpy as np
import matplotlib.pyplot as p
q1=-3e-9
q2=7e-9
k=9e9
pq1=np.array([0.2,0.3,0])
pq2=np.array([-0.3,0.1,0])
p1=np.array([-0.1,-0.2,0])
p2=np.array([0,0.4,0])
r1=p1-pq1
r1mod=np.linalg.norm(r1)
r1cap=r1/r1mod
E1=((k*q1)/(np.square(r1mod)))*(r1cap)
r2=p1-pq2
r2mod=np.linalg.norm(r2)
r2cap=r2/r2mod
E2=((k*q2)/(np.square(r2mod)))*(r2cap)
print("E1 =",E1)
print("E2 =",E2)
print("E =",E1+E2)
# Out:
# E1 = [40.85701587 68.09502645 -0.        ]
# E2 = [ 268.81624894 -403.22437341    0.        ]
# E = [ 309.67326481 -335.12934696    0.        ]

# %%
import numpy as np
import matplotlib.pyplot as p
q1=-3e-9
q2=7e-9
k=9e9
x=float(input("X component of point = "))
y=float(input("Y component of point = "))
z=float(input("Z component of point = "))
pq1=np.array([0.2,0.3,0])
pq2=np.array([-0.3,0.1,0])
p1=np.array([x,y,z])
r1=p1-pq1
r1mod=np.linalg.norm(r1)
r1cap=r1/r1mod
E1=((k*q1)/(np.square(r1mod)))*(r1cap)
r2=p1-pq2
r2mod=np.linalg.norm(r2)
r2cap=r2/r2mod
E2=((k*q2)/(np.square(r2mod)))*(r2cap)
print("E1 =",E1)
print("E2 =",E2)
print("E =",E1+E2)
magE=np.linalg.norm(E1+E2)
print("Magnitude of E = ",magE)

# %%
import numpy as np
import matplotlib.pyplot as p
m=1
q=1
v=0.5
x=0
y=0
b=0.1
tmax=70
tsize=(70/700)
X=[]
Y=[]
vx=(v*np.cos(30))
vy=(v*np.sin(30))
T=np.arange(0,70.1,0.1)
for t in T:
  Y.append(y)
  X.append(x)
  fx=((-q)*(vy*b)*np.sin(90))
  fy=(q*(vx*b)*np.sin(90))
  ax=(fx/m)
  ay=(fy/m)
  vx=vx+(ax*0.1)
  vy=vy+(ay*0.1)
  x=x+(vx*0.1)
  y=y+(vy*0.1)
p.plot(X,Y)
p.xlabel('X')
p.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
import numpy as np
import matplotlib.pyplot as p
m=1
q=1
v=0.5
x=0
y=0
b=0.1
tmax=70
tsize=(70/700)
X=[]
Y=[]
vx=(v)
vy=0
T=np.arange(0,70.1,0.1)
for t in T:
  Y.append(y)
  X.append(x)
  fx=((-q)*(vy*b))
  fy=(q*(vx*b))
  ax=(fx/m)
  ay=(fy/m)
  vx=vx+(ax*0.1)
  vy=vy+(ay*0.1)
  x=x+(vx*0.1)
  y=y+(vy*0.1)
p.plot(X,Y)
p.xlabel('X')
p.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
import numpy as np
import matplotlib.pyplot as p
m=1
q=1
v=0.5
x=0
y=0
b=0.1
tmax=70
tsize=(70/700)
X=[]
Y=[]
vx=0
vy=0
T=np.arange(0,500,0.1)
for t in T:
  Y.append(y)
  X.append(x)
  fe=(-q*(0.4*np.sin(2*3.14*0.25*t)))
  fx=fe+((-q)*(vy*b)*np.sin(90))
  fy=(q*(vx*b)*np.sin(90))
  ax=(fx/m)
  ay=(fy/m)
  vx=vx+(ax*0.1)
  vy=vy+(ay*0.1)
  x=x+(vx*0.1)
  y=y+(vy*0.1)
p.plot(X,Y)
p.xlabel('X')
p.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
import numpy as np
import matplotlib.pyplot as p
m=1
q=1
v=0.5
x=0
y=0
b=0.1
tmax=70
tsize=(70/700)
X=[]
Y=[]
vx=0
vy=0
T=np.arange(0,500,0.1)
for t in T:
  Y.append(y)
  X.append(x)
  fe=(-q*(0.4))
  fx=fe+((-q)*(vy*b)*np.sin(90))
  fy=(q*(vx*b)*np.sin(90))
  ax=(fx/m)
  ay=(fy/m)
  vx=vx+(ax*0.1)
  vy=vy+(ay*0.1)
  x=x+(vx*0.1)
  y=y+(vy*0.1)
p.plot(X,Y)
p.xlabel('X')
p.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
import numpy as np
import matplotlib.pyplot as p
m=1
q=1
v=0.5
x=0
y=0
b=0.1
tmax=500
X=[]
Y=[]
vx=0
vy=0
T=np.arange(0,500,0.1)
for t in T:
  Y.append(y)
  X.append(x)
  ax=((q*0.4)/m)*np.sin(2*3.14*0.25*0.1)+(2*3.14*0.25*vy)
  ay=(-2*3.14*0.25*vx)
  vx=vx+(ax*0.1)
  vy=vy+(ay*0.1)
  x=x+(vx*0.1)
  y=y+(vy*0.1)
p.plot(X,Y)
p.xlabel('X')
p.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
import numpy as np
import matplotlib.pyplot as p
Y=[]
y=30
tspace=0.1
T=np.arange(0,5,0.1875)
for t in T:
     y=(((-16)*(t**2))+(60*t)+30)
     print(y)
     Y.append(y)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('Height (ft)')
ymax=max((Y))
print("Maximum Heightis=",ymax,"ft")
tmax = Y.index(ymax)
print("Time to reach maximum height=",tmax*0.1875,"s")
# Out:
# 30.0
# 40.6875
# 50.25
# 58.6875
# 66.0
# 72.1875
# 77.25
# 81.1875
# 84.0
# 85.6875
# 86.25
# 85.6875
# 84.0
# 81.1875
# 77.25
# 72.1875
# 66.0
# 58.6875
# 50.25
# 40.6875
# 30.0
# 18.1875
# 5.25
# -8.8125
# -24.0
# -40.3125
# -57.75
# Maximum Heightis= 86.25 ft
# Time to reach maximum height= 1.875 s

# %%
import numpy as np
import matplotlib.pyplot as p
Y=[]
y=30
tspace=0.1
p=np.arange(0,15,0.1875)
T=[]
for t in p:
     y=(((-16)*(t**2))+(60*t)+30)
     if y<0:
      break
     print(y)
     T.append(t)
     Y.append(y)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('Height (ft)')
ymax=max((Y))
print("Maximum Heightis=",ymax,"ft")
tmax = Y.index(ymax)
print("Time to reach maximum height=",tmax*0.1875,"s")
# Out:
# 30.0
# 40.6875
# 50.25
# 58.6875
# 66.0
# 72.1875
# 77.25
# 81.1875
# 84.0
# 85.6875
# 86.25
# 85.6875
# 84.0
# 81.1875
# 77.25
# 72.1875
# 66.0
# 58.6875
# 50.25
# 40.6875
# 30.0
# 18.1875
# 5.25
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-cb24c66ddf29> in <cell line: 15>()
#      13      T.append(t)
#      14      Y.append(y)
# ---> 15 p.plot(T,Y)
#      16 p.xlabel('Time (s)')
#      17 p.ylabel('Height (ft)')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import numpy as np
import matplotlib.pyplot as p
Y=[]
y=30
tspace=0.1
p=np.arange(0,15,0.1875)
T=[]
for t in p:
     y=(((-16)*(t**2))+(60*t)+30)
     if y<0:
      break
     print(y)
     T.append(t)
     Y.append(y)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('Height (ft)')
p.title('Simple Line Plot')
p.show()
ymax=max((Y))
print("Maximum Heightis=",ymax,"ft")
tmax = Y.index(ymax)
print("Time to reach maximum height=",tmax*0.1875,"s")
# Out:
# 30.0
# 40.6875
# 50.25
# 58.6875
# 66.0
# 72.1875
# 77.25
# 81.1875
# 84.0
# 85.6875
# 86.25
# 85.6875
# 84.0
# 81.1875
# 77.25
# 72.1875
# 66.0
# 58.6875
# 50.25
# 40.6875
# 30.0
# 18.1875
# 5.25
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-bbb92a59db3f> in <cell line: 15>()
#      13      T.append(t)
#      14      Y.append(y)
# ---> 15 p.plot(T,Y)
#      16 p.xlabel('Time (s)')
#      17 p.ylabel('Height (ft)')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import numpy as np
import matplotlib.pyplot as p
Y=[]
R=[]
y=30
g=-9.8
u=60
r=0
tspace=0.1
T=np.arange(0,5,0.1875)
for t in T:
  r=r+(((u**2)*0)/g)
  y=(((-16)*(t**2))+(60*t)+30)
  R.append(r)
  Y.append(y)
p.subplot(211)
p.plot(T,Y)
p.xlabel('Time (s)')
p.ylabel('Height(ft)')
p.title('Projectile Motion:Height vs Time')
p.subplots_adjust(hspace=0.5)
p.subplot(212)
p.plot(T,R)
p.xlabel('Time (s)')
p.ylabel('Range(ft)')
p.title('Range vs Time')
ymax=max((Y))
print("Maximum Heightis=",ymax,"ft")
tmax = Y.index(ymax)
print("Time to reach maximum height=",tmax*0.1875,"s")
print("Range=",r,"ft")
# Out:
# Maximum Heightis= 86.25 ft
# Time to reach maximum height= 1.875 s
# Range= 0.0 ft
